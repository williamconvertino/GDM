# %%
import notebook_setup
from src.visualization import visualize_loss_from_files
# Out:
# Failed to install PyTorch
# Requirements installed

# %%
visualize_loss_from_files(
  ('gdGPT_8H_1L_512E_noFF_train_results', 'Train Loss'),
  ('gdGPT_8H_1L_512E_noFF_val_results', 'Test Loss'),
  title='gdGPT noFF',
  num_epochs=1
)

# %%
visualize_loss_from_files(
  ('gdGPT_8H_1L_512E_noFF_val_results', 'Without FF'),
  ('gdGPT_8H_1L_512E_val_results', 'With FF'),
  title='gdGPT (WITH and WITHOUT FF)',
  num_epochs=1
)
# Out:
#   Cell In[3], line 3
#     ('gdGPT_8H_1L_512E_val_results', 'With FF'),f
#                                                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
visualize_loss_from_files(
  ('GPT_8H_1L_512E_noFF_val_results', 'Without FF'),
  ('GPT_8H_1L_512E_val_results', 'With FF'),
  title='GPT (WITH and WITHOUT FF)',
  num_epochs=1
)

# %%
visualize_loss_from_files(
  ('gdGPT_8H_1L_512E_val_results', 'gdGPT'),
  ('GPT_8H_1L_512E_val_results', 'GPT'),
  ('GPT_8H_1L_512E_PPE_val_results', 'PPE'),
  title='gdGPT vs GPT vs PPE (With FF)',
  num_epochs=1
)

# %%
visualize_loss_from_files(
  ('gdGPT_8H_1L_512E_noFF_val_results', 'gdGPT'),
  ('GPT_8H_1L_512E_noFF_val_results', 'GPT'),
  ('GPT_8H_1L_512E_noFF_PPE_val_results', 'PPE'),
  title='gdGPT vs GPT vs PPE (Without FF)',
  num_epochs=1
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 visualize_loss_from_files(
#       2   ('gdGPT_8H_1L_512E_noFF_val_results', 'gdGPT'),
#       3   ('GPT_8H_1L_512E_noFF_val_results', 'GPT'),
#       4   ('GPT_8H_1L_512E_noFF_PPE_val_results', 'PPE'),
#       5   title='gdGPT vs GPT vs PPE (Without FF)',
#       6   num_epochs=1
#       7 )
#
# File c:\Users\will\Desktop\gdGPT\src\visualization\visualize_loss.py:57, in visualize_loss_from_files(num_epochs, title, xlabel, ylabel, xlim, ylim, *args)
#      54 else:
#      55   file_name, label = item
# ---> 57 with open(f'{RESULTS_BASE_DIR}/{file_name}.json', 'r') as f:
#      58   data = json.load(f)
#      60 if len(item) == 3:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\will\\Desktop\\gdGPT\\src\\visualization\\../../results/GPT_8H_1L_512E_noFF_PPE_val_results.json'

# %%
visualize_loss_from_files(
  ('gdGPT_8H_1L_512E_noFF_val_results', 'gdGPT'),
  ('GPT_8H_1L_512E_noFF_val_results', 'GPT'),
  title='gdGPT vs GPT (No FF)',
  num_epochs=1
)

# %%
visualize_loss_from_files(
  ('gdGPT_8H_1L_512E_noFF_val_results', 'gdGPT'),
  ('GPT_8H_1L_512E_val_results', 'GPT'),
  title='gdGPT (NO FF) vs GPT (WITH FF)',
  num_epochs=1
)

# %%
visualize_loss_from_files(
  ('gdGPT_8H_1L_512E_val_results', 'Projected Heads'),
  ('gdGPT_8H_1L_512E_sumOut_summed_val_results', 'Summed heads'),
  title='Summed gdGPT vs W_o gdGPT',
  num_epochs=1
)

# %%
visualize_loss_from_files(
  ('gdGPT_8H_1L_512E_sumOut_summed_val_results', 'With FF'),
  ('gdGPT_8H_1L_512E_noFF_sumOut_summed_val_results', 'Without FF'),
  title='Summed gdGPT (With and Without FF)',
  num_epochs=1
)
